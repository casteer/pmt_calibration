# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
    
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pmt_calibration as pmt

p = pmt.drs4_data_processor(str('./'))

# Set bounds in the fitting
# p.set_consistent_bounds()

# Refit the data
p.recalibrate()

# 
p.plot_charge_resolution()
p.plot_gain()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Processing  pmt_ctrl5p05_led_thresh_charge.txt
# Voltage (kV):  1262.5
# 578
# Processing  pmt_ctrl5p0_led_thresh_charge.txt
# Voltage (kV):  1250.0
# 507
# Processing  pmt_ctrl4p75_led_thresh_charge.txt
# Voltage (kV):  1187.5
# 487
# Processing  pmt_ctrl4p5_led_thresh_charge.txt
# Voltage (kV):  1125.0
# 491
# Processing  pmt_ctrl4p0_led_thresh_charge.txt
# Voltage (kV):  1000.0
# 530
# Processing  pmt_ctrl4p25_led_thresh_charge.txt
# Voltage (kV):  1062.5
# 631
# Voltage (kV):  1262.5
# Resolution Level :  4  Chi2 :  2.16663681782e-08
# Resolution Level :  3  Chi2 :  5.18568249747e-07
# Resolution Level :  2  Chi2 :  5.95910975846e-08
# Resolution Level :  1  Chi2 :  5.87221427973e-08
#
# ...
# FIT PARAMETERS
# ...
# Q0  	 = 	1.732878 +/- 0.001970
# sig0  	 = 	0.132684 +/- 0.003886
# Q1  	 = 	0.277377 +/- 0.009176
# sig1  	 = 	0.226492 +/- 0.007022
# A  	 = 	9.689530 +/- 33171.824940
# ...
